# %%
import pandas as pd

# %%
pd.read_csv(r'C:\Users\Rajan\Downloads\sales_data_final.csv')
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011    1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# 10       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 11       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 12     ES-2011-4869686    1/3/2011    1/7/2011  Standard Class
# 13       IN-2011-33652    1/3/2011    1/9/2011  Standard Class
# ...

# %%
df = pd.read_csv(r'C:\Users\Rajan\Downloads\sales_data_final.csv')

# %%
df.head(3)
# Out:
#         order_id order_date ship_date       ship_mode    customer_name  \
# 0   AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1  IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2   HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
#
#     segment            state    country  market   region  ...   \
# 0  Consumer      Constantine    Algeria  Africa   Africa  ...
# 1  Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2  Consumer         Budapest    Hungary    EMEA     EMEA  ...
#
#           category sub_category              product_name sales quantity  \
# 0  Office Supplies      Storage       Tenex Lockers, Blue   408        2
# 1  Office Supplies     Supplies  Acme Trimmer, High Speed   120        3
# 2  Office Supplies      Storage   Tenex Box, Single Width    66        4
#
#    discount   profit  shipping_cost  order_priority  year
# 0       0.0  106.140          35.46          Medium  2011
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df['order_date']
# Out:
# 0          1/1/2011
# 1          1/1/2011
# 2          1/1/2011
# 3          1/1/2011
# 4          1/1/2011
# 5          1/1/2011
# 6          1/2/2011
# 7          1/3/2011
# 8          1/3/2011
# 9          1/3/2011
# 10         1/3/2011
# 11         1/3/2011
# 12         1/3/2011
# 13         1/3/2011
# 14         1/3/2011
# 15         1/3/2011
# 16         1/3/2011
# 17         1/3/2011
# 18         1/3/2011
# 19         1/3/2011
# 20         1/3/2011
# 21         1/3/2011
# 22         1/3/2011
# 23         1/3/2011
# 24         1/3/2011
# 25         1/3/2011
# 26         1/3/2011
# 27         1/4/2011
# 28         1/4/2011
# 29         1/4/2011
#             ...
# 51260    12/31/2014
# 51261    12/31/2014
# 51262    12/31/2014
# 51263    12/31/2014
# 51264    12/31/2014
# 51265    12/31/2014
# 51266    12/31/2014
# 51267    12/31/2014
# 51268    12/31/2014
# 51269    12/31/2014
# 51270    12/31/2014
# 51271    12/31/2014
# 51272    12/31/2014
# 51273    12/31/2014
# ...

# %%
type(df['order_date'])
# Out:
# pandas.core.series.Series

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.tail
# Out:
# <bound method NDFrame.tail of               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011    1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# 10       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 11       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 12     ES-2011-4869686    1/3/2011    1/7/2011  Standard Class
# ...

# %%
df['profit']
# Out:
# 0        106.1400
# 1         36.0360
# 2         29.6400
# 3        -26.0550
# 4         37.7700
# 5         15.3420
# 6          3.1200
# 7        110.4120
# 8       -319.4640
# 9        253.3200
# 10      -122.8005
# 11       -70.3995
# 12       290.4300
# 13        50.1300
# 14       -95.6760
# 15        44.8800
# 16        42.9000
# 17         3.4200
# 18       -26.4120
# 19       -45.9018
# 20         4.7430
# 21         7.7700
# 22         8.7000
# 23        26.7600
# 24        17.0700
# 25         0.5460
# 26         4.1700
# 27       609.8400
# 28        13.2800
# 29         3.6000
#            ...
# 51260     19.7910
# 51261     16.4400
# 51262      4.0530
# 51263     10.8600
# 51264      6.4000
# 51265      6.6600
# 51266    -14.2356
# 51267     -9.6900
# 51268      7.4400
# 51269    153.0900
# 51270     24.7500
# 51271      4.3200
# 51272     -6.4200
# 51273      9.1200
# 51274    -25.2780
# 51275    -37.2660
# 51276     17.2800
# 51277      1.2000
# 51278      3.9600
# ...

# %%
df['profit','year']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3062             try:
# -> 3063                 return self._engine.get_loc(key)
#    3064             except KeyError:
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('profit', 'year')
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-113-b1052f81e3d1> in <module>()
# ----> 1 df['profit','year']
#
# ...

# %%
df[['profit','year']]
# Out:
#          profit  year
# 0      106.1400  2011
# 1       36.0360  2011
# 2       29.6400  2011
# 3      -26.0550  2011
# 4       37.7700  2011
# 5       15.3420  2011
# 6        3.1200  2011
# 7      110.4120  2011
# 8     -319.4640  2011
# 9      253.3200  2011
# 10    -122.8005  2011
# 11     -70.3995  2011
# 12     290.4300  2011
# 13      50.1300  2011
# 14     -95.6760  2011
# 15      44.8800  2011
# 16      42.9000  2011
# 17       3.4200  2011
# 18     -26.4120  2011
# 19     -45.9018  2011
# 20       4.7430  2011
# 21       7.7700  2011
# 22       8.7000  2011
# 23      26.7600  2011
# 24      17.0700  2011
# 25       0.5460  2011
# 26       4.1700  2011
# 27     609.8400  2011
# 28      13.2800  2011
# 29       3.6000  2011
# ...         ...   ...
# 51260   19.7910  2014
# 51261   16.4400  2014
# 51262    4.0530  2014
# 51263   10.8600  2014
# 51264    6.4000  2014
# 51265    6.6600  2014
# 51266  -14.2356  2014
# 51267   -9.6900  2014
# 51268    7.4400  2014
# ...

# %%
df[['profit']]
# Out:
#          profit
# 0      106.1400
# 1       36.0360
# 2       29.6400
# 3      -26.0550
# 4       37.7700
# 5       15.3420
# 6        3.1200
# 7      110.4120
# 8     -319.4640
# 9      253.3200
# 10    -122.8005
# 11     -70.3995
# 12     290.4300
# 13      50.1300
# 14     -95.6760
# 15      44.8800
# 16      42.9000
# 17       3.4200
# 18     -26.4120
# 19     -45.9018
# 20       4.7430
# 21       7.7700
# 22       8.7000
# 23      26.7600
# 24      17.0700
# 25       0.5460
# 26       4.1700
# 27     609.8400
# 28      13.2800
# 29       3.6000
# ...         ...
# 51260   19.7910
# 51261   16.4400
# 51262    4.0530
# 51263   10.8600
# 51264    6.4000
# 51265    6.6600
# 51266  -14.2356
# 51267   -9.6900
# 51268    7.4400
# 51269  153.0900
# 51270   24.7500
# 51271    4.3200
# 51272   -6.4200
# 51273    9.1200
# 51274  -25.2780
# 51275  -37.2660
# 51276   17.2800
# 51277    1.2000
# 51278    3.9600
# 51279    8.2500
# 51280    6.8400
# 51281    6.4750
# 51282    6.1200
# ...

# %%
df['profit']
# Out:
# 0        106.1400
# 1         36.0360
# 2         29.6400
# 3        -26.0550
# 4         37.7700
# 5         15.3420
# 6          3.1200
# 7        110.4120
# 8       -319.4640
# 9        253.3200
# 10      -122.8005
# 11       -70.3995
# 12       290.4300
# 13        50.1300
# 14       -95.6760
# 15        44.8800
# 16        42.9000
# 17         3.4200
# 18       -26.4120
# 19       -45.9018
# 20         4.7430
# 21         7.7700
# 22         8.7000
# 23        26.7600
# 24        17.0700
# 25         0.5460
# 26         4.1700
# 27       609.8400
# 28        13.2800
# 29         3.6000
#            ...
# 51260     19.7910
# 51261     16.4400
# 51262      4.0530
# 51263     10.8600
# 51264      6.4000
# 51265      6.6600
# 51266    -14.2356
# 51267     -9.6900
# 51268      7.4400
# 51269    153.0900
# 51270     24.7500
# 51271      4.3200
# 51272     -6.4200
# 51273      9.1200
# 51274    -25.2780
# 51275    -37.2660
# 51276     17.2800
# 51277      1.2000
# 51278      3.9600
# ...

# %%
type(df['profit'])
# Out:
# pandas.core.series.Series

# %%
type(df[['profit']])
# Out:
# pandas.core.frame.DataFrame

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df[['order_id','product_id','quantity']]
# Out:
#               order_id        product_id  quantity
# 0         AG-2011-2040  OFF-TEN-10000025         2
# 1        IN-2011-47883   OFF-SU-10000618         3
# 2         HU-2011-1220  OFF-TEN-10001585         4
# 3      IT-2011-3647632   OFF-PA-10001492         3
# 4        IN-2011-47883   FUR-FU-10003447         5
# 5        IN-2011-47883   OFF-PA-10001968         2
# 6         CA-2011-1510  TEC-OKI-10002750         1
# 7        IN-2011-79397   OFF-AP-10000304         1
# 8        ID-2011-80230   TEC-CO-10004182         4
# 9         IZ-2011-4680  FUR-NOV-10002791         4
# 10       IN-2011-65159   OFF-ST-10003020         3
# 11       IN-2011-65159   FUR-TA-10002797         1
# 12     ES-2011-4869686   FUR-BO-10000728         7
# 13       IN-2011-33652   TEC-CO-10000594         1
# 14       ID-2011-80230   FUR-CH-10000214         2
# 15      MX-2011-160234   TEC-PH-10002647         4
# 16         IR-2011-770  OFF-BRE-10003081         2
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region  ...   \
# 0     Consumer      Constantine    Algeria  Africa   Africa  ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania  ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA  ...
# 3  Home Office        Stockholm     Sweden      EU    North  ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania  ...
#
#           category sub_category                 product_name sales quantity  \
# ...

# %%
df.describe()
# Out:
#            quantity      discount        profit  shipping_cost          year
# count  51290.000000  51290.000000  51290.000000   51290.000000  51290.000000
# mean       3.476545      0.142908     28.641740      26.375915   2012.777208
# std        2.278766      0.212280    174.424113      57.296804      1.098931
# min        1.000000      0.000000  -6599.978000       0.000000   2011.000000
# 25%        2.000000      0.000000      0.000000       2.610000   2012.000000
# 50%        3.000000      0.000000      9.240000       7.790000   2013.000000
# 75%        5.000000      0.200000     36.810000      24.450000   2014.000000
# max       14.000000      0.850000   8399.976000     933.570000   2014.000000

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.dtypes == 'object'
# Out:
# order_id           True
# order_date         True
# ship_date          True
# ship_mode          True
# customer_name      True
# segment            True
# state              True
# country            True
# market             True
# region             True
# product_id         True
# category           True
# sub_category       True
# product_name       True
# sales              True
# quantity          False
# discount          False
# profit            False
# shipping_cost     False
# order_priority     True
# year              False
# dtype: bool

# %%
type(df.dtypes)
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes == 'object']
# Out:
# order_id          object
# order_date        object
# ship_date         object
# ship_mode         object
# customer_name     object
# segment           object
# state             object
# country           object
# market            object
# region            object
# product_id        object
# category          object
# sub_category      object
# product_name      object
# sales             object
# order_priority    object
# dtype: object

# %%
type(df.dtypes == 'object')
# Out:
# pandas.core.series.Series

# %%
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'order_priority'],
#       dtype='object')

# %%
df[df.dtypes[df.dtypes == 'object'].index]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011    1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# 10       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 11       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 12     ES-2011-4869686    1/3/2011    1/7/2011  Standard Class
# 13       IN-2011-33652    1/3/2011    1/9/2011  Standard Class
# ...

# %%
df[df.dtypes[df.dtypes == 'object'].index].describe()
# Out:
#               order_id order_date   ship_date       ship_mode  \
# count            51290      51290       51290           51290
# unique           25035       1430        1464               4
# top     CA-2014-100111  6/18/2014  11/22/2014  Standard Class
# freq                14        135         130           30775
#
#           customer_name   segment       state        country market   region  \
# count             51290     51290       51290          51290  51290    51290
# unique              795         3        1094            147      7       13
# top     Muhammed Yedwab  Consumer  California  United States   APAC  Central
# freq                108     26518        2001           9994  11002    11117
#
#              product_id         category sub_category product_name  sales  \
# count             51290            51290        51290        51290  51290
# unique            10292                3           17         3788   2246
# ...

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# dtype: object

# %%
df.dtypes[df.dtypes == 'float64']
# Out:
# discount         float64
# profit           float64
# shipping_cost    float64
# dtype: object

# %%
df.dtypes[df.dtypes == 'float64'].index
# Out:
# Index(['discount', 'profit', 'shipping_cost'], dtype='object')

# %%
df[df.dtypes[df.dtypes == 'float64'].index]
# Out:
#        discount    profit  shipping_cost
# 0          0.00  106.1400          35.46
# 1          0.10   36.0360           9.72
# 2          0.00   29.6400           8.17
# 3          0.50  -26.0550           4.82
# 4          0.10   37.7700           4.70
# 5          0.10   15.3420           1.80
# 6          0.00    3.1200          24.10
# 7          0.10  110.4120         125.32
# 8          0.40 -319.4640         107.10
# 9          0.00  253.3200          81.26
# 10         0.45 -122.8005          33.75
# 11         0.55  -70.3995          21.32
# 12         0.00  290.4300          12.56
# 13         0.00   50.1300          10.40
# 14         0.40  -95.6760          10.07
# 15         0.00   44.8800           8.43
# 16         0.00   42.9000           8.41
# 17         0.40    3.4200           8.34
# 18         0.40  -26.4120           8.17
# 19         0.47  -45.9018           7.74
# 20         0.10    4.7430           7.46
# 21         0.00    7.7700           5.91
# ...

# %%
df.order_id
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
# 5          IN-2011-47883
# 6           CA-2011-1510
# 7          IN-2011-79397
# 8          ID-2011-80230
# 9           IZ-2011-4680
# 10         IN-2011-65159
# 11         IN-2011-65159
# 12       ES-2011-4869686
# 13         IN-2011-33652
# 14         ID-2011-80230
# 15        MX-2011-160234
# 16           IR-2011-770
# 17         ID-2011-80230
# 18         ID-2011-80230
# 19         ID-2011-12596
# 20         IN-2011-79397
# 21          IR-2011-7690
# 22           IR-2011-770
# 23          TZ-2011-7370
# 24          IZ-2011-4680
# 25         IN-2011-65159
# 26           IR-2011-770
# 27        MX-2011-111255
# 28        MX-2011-140641
# 29        MX-2011-158771
#               ...
# 51260     CA-2014-143259
# 51261     MX-2014-116267
# 51262       TZ-2014-8350
# 51263     MX-2014-110527
# 51264     MX-2014-110527
# 51265      ID-2014-58418
# ...

# %%
df['order_id']
# Out:
# 0           AG-2011-2040
# 1          IN-2011-47883
# 2           HU-2011-1220
# 3        IT-2011-3647632
# 4          IN-2011-47883
# 5          IN-2011-47883
# 6           CA-2011-1510
# 7          IN-2011-79397
# 8          ID-2011-80230
# 9           IZ-2011-4680
# 10         IN-2011-65159
# 11         IN-2011-65159
# 12       ES-2011-4869686
# 13         IN-2011-33652
# 14         ID-2011-80230
# 15        MX-2011-160234
# 16           IR-2011-770
# 17         ID-2011-80230
# 18         ID-2011-80230
# 19         ID-2011-12596
# 20         IN-2011-79397
# 21          IR-2011-7690
# 22           IR-2011-770
# 23          TZ-2011-7370
# 24          IZ-2011-4680
# 25         IN-2011-65159
# 26           IR-2011-770
# 27        MX-2011-111255
# 28        MX-2011-140641
# 29        MX-2011-158771
#               ...
# 51260     CA-2014-143259
# 51261     MX-2014-116267
# 51262       TZ-2014-8350
# 51263     MX-2014-110527
# 51264     MX-2014-110527
# 51265      ID-2014-58418
# ...

# %%
df['order_id'][1:4]
# Out:
# 1      IN-2011-47883
# 2       HU-2011-1220
# 3    IT-2011-3647632
# Name: order_id, dtype: object

# %%
df['order_id'][1:40:2]
# Out:
# 1       IN-2011-47883
# 3     IT-2011-3647632
# 5       IN-2011-47883
# 7       IN-2011-79397
# 9        IZ-2011-4680
# 11      IN-2011-65159
# 13      IN-2011-33652
# 15     MX-2011-160234
# 17      ID-2011-80230
# 19      ID-2011-12596
# 21       IR-2011-7690
# 23       TZ-2011-7370
# 25      IN-2011-65159
# 27     MX-2011-111255
# 29     MX-2011-158771
# 31     MX-2011-111255
# 33     US-2011-136007
# 35     MX-2011-159373
# 37    IT-2011-2942451
# 39      IN-2011-33036
# Name: order_id, dtype: object

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011    1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# 10       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 11       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 12     ES-2011-4869686    1/3/2011    1/7/2011  Standard Class
# 13       IN-2011-33652    1/3/2011    1/9/2011  Standard Class
# ...

# %%
df['category1']= "sudh"

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011    1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# 10       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 11       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 12     ES-2011-4869686    1/3/2011    1/7/2011  Standard Class
# 13       IN-2011-33652    1/3/2011    1/9/2011  Standard Class
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1'],
#       dtype='object')

# %%
df['order_id'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 51260    False
# 51261    False
# 51262    False
# 51263    False
# 51264    False
# 51265    False
# 51266    False
# 51267    False
# 51268    False
# 51269    False
# 51270    False
# 51271    False
# 51272    False
# 51273    False
# 51274    False
# 51275    False
# 51276    False
# 51277    False
# 51278    False
# 51279    False
# 51280    False
# 51281    False
# 51282    False
# 51283    False
# 51284    False
# 51285    False
# 51286    False
# ...

# %%
pd.read_csv(r'C:\Users\Rajan\Downloads\DressSales.csv')
# Out:
#        Dress_ID  29/8/2013  31/8/2013  2/9/2013  4/9/2013  6/9/2013  8/9/2013  \
# 0    1006032852       2114       2274      2491      2660      2727      2887
# 1    1212192089        151        275       570       750       813      1066
# 2    1190380701          6          7         7         7         8         8
# 3     966005983       1005       1128      1326      1455      1507      1621
# 4     876339541        996       1175      1304      1396      1432      1559
# 5    1068332458          4          5        11        13        13        13
# 6    1220707172         45         61       131       165       176       209
# 7    1219677488          4         13        55        73        76        89
# 8    1113094204          5          6        10        12        13        15
# 9     985292672          9         11        12        12        12        12
# 10   1117293701         15         28        42        49        49        55
# ...

# %%
df1=pd.read_csv(r'C:\Users\Rajan\Downloads\sales_data_final.csv')

# %%
df1.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year'],
#       dtype='object')

# %%
df1['profit'].isnull()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 51260    False
# 51261    False
# 51262    False
# 51263    False
# 51264    False
# 51265    False
# 51266    False
# 51267    False
# 51268    False
# 51269    False
# 51270    False
# 51271    False
# 51272    False
# 51273    False
# 51274    False
# 51275    False
# 51276    False
# 51277    False
# 51278    False
# 51279    False
# 51280    False
# 51281    False
# 51282    False
# 51283    False
# 51284    False
# 51285    False
# 51286    False
# ...

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011    1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# 10       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 11       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 12     ES-2011-4869686    1/3/2011    1/7/2011  Standard Class
# 13       IN-2011-33652    1/3/2011    1/9/2011  Standard Class
# ...

# %%
df.columns
# Out:
# Index(['order_id', 'order_date', 'ship_date', 'ship_mode', 'customer_name',
#        'segment', 'state', 'country', 'market', 'region', 'product_id',
#        'category', 'sub_category', 'product_name', 'sales', 'quantity',
#        'discount', 'profit', 'shipping_cost', 'order_priority', 'year',
#        'category1'],
#       dtype='object')

# %%
df['profit'] == max(df['profit'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 51260    False
# 51261    False
# 51262    False
# 51263    False
# 51264    False
# 51265    False
# 51266    False
# 51267    False
# 51268    False
# 51269    False
# 51270    False
# 51271    False
# 51272    False
# 51273    False
# 51274    False
# 51275    False
# 51276    False
# 51277    False
# 51278    False
# 51279    False
# 51280    False
# 51281    False
# 51282    False
# 51283    False
# 51284    False
# 51285    False
# 51286    False
# ...

# %%
df[df['profit'] == max(df['profit'])]
# Out:
#              order_id order_date   ship_date       ship_mode customer_name  \
# 29530  CA-2013-118689  10/3/2013  10/10/2013  Standard Class  Tamara Chand
#
#          segment    state        country market   region    ...     \
# 29530  Corporate  Indiana  United States     US  Central    ...
#
#       sub_category                           product_name   sales quantity  \
# 29530      Copiers  Canon imageCLASS 2200 Advanced Copier  17,500        5
#
#       discount    profit  shipping_cost  order_priority  year category1
# 29530      0.0  8399.976         349.07          Medium  2013      sudh
#
# [1 rows x 22 columns]

# %%
df[df['profit'] == max(df['profit'])]['customer_name']
# Out:
# 29530    Tamara Chand
# Name: customer_name, dtype: object

# %%
df['country']
# Out:
# 0               Algeria
# 1             Australia
# 2               Hungary
# 3                Sweden
# 4             Australia
# 5             Australia
# 6                Canada
# 7             Australia
# 8           New Zealand
# 9                  Iraq
# 10          Philippines
# 11          Philippines
# 12       United Kingdom
# 13             Malaysia
# 14          New Zealand
# 15            Guatemala
# 16                 Iran
# 17          New Zealand
# 18          New Zealand
# 19             Thailand
# 20            Australia
# 21                 Iran
# 22                 Iran
# 23             Tanzania
# 24                 Iraq
# 25          Philippines
# 26                 Iran
# 27               Brazil
# 28               Mexico
# 29                 Cuba
#               ...
# 51260     United States
# 51261            Brazil
# 51262          Tanzania
# 51263         Nicaragua
# 51264         Nicaragua
# 51265             China
# 51266          Thailand
# ...

# %%
df['country']=='Sweden'
# Out:
# 0        False
# 1        False
# 2        False
# 3         True
# 4        False
# 5        False
# 6        False
# 7        False
# 8        False
# 9        False
# 10       False
# 11       False
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27       False
# 28       False
# 29       False
#          ...
# 51260    False
# 51261    False
# 51262    False
# 51263    False
# 51264    False
# 51265    False
# 51266    False
# 51267    False
# 51268    False
# 51269    False
# 51270    False
# 51271    False
# 51272    False
# 51273    False
# 51274    False
# 51275    False
# 51276    False
# 51277    False
# 51278    False
# 51279    False
# 51280    False
# 51281    False
# 51282    False
# 51283    False
# 51284    False
# 51285    False
# 51286    False
# ...

# %%
df[df['country']=='Sweden']
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 168    IT-2011-5951216   1/13/2011   1/20/2011  Standard Class
# 477    IT-2011-5645183    2/3/2011    2/5/2011    Second Class
# 1342   IT-2011-5233011   3/31/2011    4/6/2011  Standard Class
# 1554   IT-2011-2419493   4/12/2011   4/13/2011     First Class
# 2080   IT-2011-2204228    5/9/2011   5/14/2011  Standard Class
# 2085   IT-2011-2660642   5/10/2011   5/12/2011    Second Class
# 2094   IT-2011-2660642   5/10/2011   5/12/2011    Second Class
# 2096   IT-2011-2660642   5/10/2011   5/12/2011    Second Class
# 2422   IT-2011-3515682   5/27/2011   5/30/2011     First Class
# 2927   ES-2011-3286627   6/15/2011   6/17/2011     First Class
# 2931   ES-2011-3286627   6/15/2011   6/17/2011     First Class
# 2952   ES-2011-3286627   6/15/2011   6/17/2011     First Class
# 2983   IT-2011-5810579   6/17/2011   6/21/2011  Standard Class
# ...

# %%
len(df[df['country']=='Sweden'])
# Out:
# 203

# %%
df['shipping_cost']>20
# Out:
# 0         True
# 1        False
# 2        False
# 3        False
# 4        False
# 5        False
# 6         True
# 7         True
# 8         True
# 9         True
# 10        True
# 11        True
# 12       False
# 13       False
# 14       False
# 15       False
# 16       False
# 17       False
# 18       False
# 19       False
# 20       False
# 21       False
# 22       False
# 23       False
# 24       False
# 25       False
# 26       False
# 27        True
# 28        True
# 29       False
#          ...
# 51260    False
# 51261    False
# 51262    False
# 51263    False
# 51264    False
# 51265    False
# 51266    False
# 51267    False
# 51268    False
# 51269    False
# 51270    False
# 51271    False
# 51272    False
# 51273    False
# 51274    False
# 51275    False
# 51276    False
# 51277    False
# 51278    False
# 51279    False
# 51280    False
# 51281    False
# 51282    False
# 51283    False
# 51284    False
# 51285    False
# 51286    False
# ...

# %%
df[df['shipping_cost']>20]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# 10       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 11       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 27      MX-2011-111255    1/4/2011    1/9/2011    Second Class
# 28      MX-2011-140641    1/4/2011    1/9/2011  Standard Class
# 43      MX-2011-109267    1/5/2011    1/9/2011  Standard Class
# 44     ES-2011-3848439    1/5/2011    1/7/2011     First Class
# 50     ES-2011-5496179    1/6/2011    1/9/2011    Second Class
# 58      CA-2011-167199    1/7/2011   1/11/2011  Standard Class
# 59      CA-2011-167199    1/7/2011   1/11/2011  Standard Class
# ...

# %%
len(df[df['shipping_cost']>20])
# Out:
# 14843

# %%
df[df['shipping_cost']>80]['country']
# Out:
# 7             Australia
# 8           New Zealand
# 9                  Iraq
# 27               Brazil
# 43               Mexico
# 58        United States
# 59        United States
# 83               Angola
# 84                China
# 100           Australia
# 101             Hungary
# 102             Hungary
# 103               Egypt
# 125      United Kingdom
# 126              Mexico
# 173       United States
# 174       United States
# 175       United States
# 199             Germany
# 200              France
# 213         El Salvador
# 225            Tanzania
# 230              Zambia
# 241              Angola
# 242              Mexico
# 257           Nicaragua
# 258            Mongolia
# 259       United States
# 287               Italy
# 302           Nicaragua
#               ...
# 50784         Nicaragua
# 50785         Guatemala
# 50856           Germany
# 50857             China
# 50858     United States
# 50859           Germany
# 50860             Japan
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region    ...     \
# 0     Consumer      Constantine    Algeria  Africa   Africa    ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania    ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA    ...
# 3  Home Office        Stockholm     Sweden      EU    North    ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania    ...
#
#   sub_category                 product_name sales quantity discount   profit  \
# ...

# %%
df[(df['shipping_cost']>100) & (df['profit']<10)]
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 257     MX-2011-146584   1/21/2011   1/27/2011  Standard Class
# 451    ES-2011-1640672    2/2/2011    2/5/2011     First Class
# 625      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 626      ID-2011-47575   2/15/2011   2/21/2011  Standard Class
# 801      ID-2011-72894   2/28/2011    3/3/2011     First Class
# 802      ID-2011-72894   2/28/2011    3/3/2011     First Class
# 1072    US-2011-148838   3/17/2011   3/21/2011  Standard Class
# 1350   IT-2011-3468929    4/1/2011    4/4/2011     First Class
# 1410    MX-2011-104794    4/4/2011    4/8/2011  Standard Class
# 1468   IT-2011-3316894    4/6/2011    4/8/2011     First Class
# 1652   ES-2011-2835499   4/18/2011   4/20/2011    Second Class
# 1653   IT-2011-5063480   4/18/2011   4/25/2011  Standard Class
# 1698    CA-2011-134572   4/20/2011   4/22/2011    Second Class
# ...

# %%
len(df[(df['shipping_cost']>100) & (df['profit']<10)])
# Out:
# 604

# %%
df.dtypes
# Out:
# order_id           object
# order_date         object
# ship_date          object
# ship_mode          object
# customer_name      object
# segment            object
# state              object
# country            object
# market             object
# region             object
# product_id         object
# category           object
# sub_category       object
# product_name       object
# sales              object
# quantity            int64
# discount          float64
# profit            float64
# shipping_cost     float64
# order_priority     object
# year                int64
# category1          object
# dtype: object

# %%
pd.to_datetime(df['order_date'])
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
# 5       2011-01-01
# 6       2011-01-02
# 7       2011-01-03
# 8       2011-01-03
# 9       2011-01-03
# 10      2011-01-03
# 11      2011-01-03
# 12      2011-01-03
# 13      2011-01-03
# 14      2011-01-03
# 15      2011-01-03
# 16      2011-01-03
# 17      2011-01-03
# 18      2011-01-03
# 19      2011-01-03
# 20      2011-01-03
# 21      2011-01-03
# 22      2011-01-03
# 23      2011-01-03
# 24      2011-01-03
# 25      2011-01-03
# 26      2011-01-03
# 27      2011-01-04
# 28      2011-01-04
# 29      2011-01-04
#            ...
# 51260   2014-12-31
# 51261   2014-12-31
# 51262   2014-12-31
# 51263   2014-12-31
# 51264   2014-12-31
# 51265   2014-12-31
# 51266   2014-12-31
# 51267   2014-12-31
# 51268   2014-12-31
# 51269   2014-12-31
# 51270   2014-12-31
# 51271   2014-12-31
# 51272   2014-12-31
# 51273   2014-12-31
# 51274   2014-12-31
# 51275   2014-12-31
# ...

# %%
date = pd.to_datetime(df['order_date'])
date
# Out:
# 0       2011-01-01
# 1       2011-01-01
# 2       2011-01-01
# 3       2011-01-01
# 4       2011-01-01
# 5       2011-01-01
# 6       2011-01-02
# 7       2011-01-03
# 8       2011-01-03
# 9       2011-01-03
# 10      2011-01-03
# 11      2011-01-03
# 12      2011-01-03
# 13      2011-01-03
# 14      2011-01-03
# 15      2011-01-03
# 16      2011-01-03
# 17      2011-01-03
# 18      2011-01-03
# 19      2011-01-03
# 20      2011-01-03
# 21      2011-01-03
# 22      2011-01-03
# 23      2011-01-03
# 24      2011-01-03
# 25      2011-01-03
# 26      2011-01-03
# 27      2011-01-04
# 28      2011-01-04
# 29      2011-01-04
#            ...
# 51260   2014-12-31
# 51261   2014-12-31
# 51262   2014-12-31
# 51263   2014-12-31
# 51264   2014-12-31
# 51265   2014-12-31
# 51266   2014-12-31
# 51267   2014-12-31
# 51268   2014-12-31
# 51269   2014-12-31
# 51270   2014-12-31
# 51271   2014-12-31
# 51272   2014-12-31
# 51273   2014-12-31
# 51274   2014-12-31
# 51275   2014-12-31
# ...

# %%
type(date[0])
# Out:
# pandas._libs.tslibs.timestamps.Timestamp

# %%
df['converted_order_date'] = pd.to_datetime(df['order_date'])

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011    1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# 10       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 11       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 12     ES-2011-4869686    1/3/2011    1/7/2011  Standard Class
# 13       IN-2011-33652    1/3/2011    1/9/2011  Standard Class
# ...

# %%
df['order_date_year']= df['converted_order_date'].dt.year
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011    1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# 10       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 11       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 12     ES-2011-4869686    1/3/2011    1/7/2011  Standard Class
# 13       IN-2011-33652    1/3/2011    1/9/2011  Standard Class
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region       ...        \
# 0     Consumer      Constantine    Algeria  Africa   Africa       ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania       ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA       ...
# 3  Home Office        Stockholm     Sweden      EU    North       ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania       ...
#
#                   product_name sales quantity discount   profit  \
# ...

# %%
df['order_date_month']= df['converted_order_date'].dt.month
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011    1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# 10       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 11       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 12     ES-2011-4869686    1/3/2011    1/7/2011  Standard Class
# 13       IN-2011-33652    1/3/2011    1/9/2011  Standard Class
# ...

# %%
df['order_date_week']=df['converted_order_date'].dt.week
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011    1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# 10       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 11       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 12     ES-2011-4869686    1/3/2011    1/7/2011  Standard Class
# 13       IN-2011-33652    1/3/2011    1/9/2011  Standard Class
# ...

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region       ...        \
# 0     Consumer      Constantine    Algeria  Africa   Africa       ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania       ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA       ...
# 3  Home Office        Stockholm     Sweden      EU    North       ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania       ...
#
#   quantity discount   profit shipping_cost order_priority  year  \
# ...

# %%
df
# Out:
#               order_id  order_date   ship_date       ship_mode  \
# 0         AG-2011-2040    1/1/2011    1/6/2011  Standard Class
# 1        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 2         HU-2011-1220    1/1/2011    1/5/2011    Second Class
# 3      IT-2011-3647632    1/1/2011    1/5/2011    Second Class
# 4        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 5        IN-2011-47883    1/1/2011    1/8/2011  Standard Class
# 6         CA-2011-1510    1/2/2011    1/6/2011  Standard Class
# 7        IN-2011-79397    1/3/2011    1/3/2011        Same Day
# 8        ID-2011-80230    1/3/2011    1/9/2011  Standard Class
# 9         IZ-2011-4680    1/3/2011    1/7/2011  Standard Class
# 10       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 11       IN-2011-65159    1/3/2011    1/7/2011    Second Class
# 12     ES-2011-4869686    1/3/2011    1/7/2011  Standard Class
# 13       IN-2011-33652    1/3/2011    1/9/2011  Standard Class
# ...

# %%
df[['converted_order_date','order_date_week']] #Showing jan as 52nd week and December as 1st Week. 
#So basically it shows how much week is left for the year
# Out:
#       converted_order_date  order_date_week
# 0               2011-01-01               52
# 1               2011-01-01               52
# 2               2011-01-01               52
# 3               2011-01-01               52
# 4               2011-01-01               52
# 5               2011-01-01               52
# 6               2011-01-02               52
# 7               2011-01-03                1
# 8               2011-01-03                1
# 9               2011-01-03                1
# 10              2011-01-03                1
# 11              2011-01-03                1
# 12              2011-01-03                1
# 13              2011-01-03                1
# 14              2011-01-03                1
# 15              2011-01-03                1
# 16              2011-01-03                1
# 17              2011-01-03                1
# 18              2011-01-03                1
# 19              2011-01-03                1
# ...

# %%
#In which month, we are going to do most sales --> Group by operation on month and then count
#In Pandas, this is equivalent to value_counts function
df['order_date_month'].value_counts()
# Out:
# 11    6342
# 12    6302
# 9     5975
# 6     5331
# 8     5078
# 10    4490
# 5     3747
# 7     3166
# 4     3057
# 3     3035
# 1     2599
# 2     2168
# Name: order_date_month, dtype: int64

# %%
df.columns
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-138-b666bf274d0a> in <module>()
# ----> 1 df.columns
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4366         if (name in self._internal_names_set or name in self._metadata or
#    4367                 name in self._accessors):
# -> 4368             return object.__getattribute__(self, name)
#    4369         else:
#    4370             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# AttributeError: 'Series' object has no attribute 'columns'

# %%
#cost ot company computation
df['cost_to_company']= df['discount'] + df['shipping_cost']

# %%
df.head()
# Out:
#           order_id order_date ship_date       ship_mode    customer_name  \
# 0     AG-2011-2040   1/1/2011  1/6/2011  Standard Class  Toby Braunhardt
# 1    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
# 2     HU-2011-1220   1/1/2011  1/5/2011    Second Class    Annie Thurman
# 3  IT-2011-3647632   1/1/2011  1/5/2011    Second Class     Eugene Moren
# 4    IN-2011-47883   1/1/2011  1/8/2011  Standard Class      Joseph Holt
#
#        segment            state    country  market   region       ...        \
# 0     Consumer      Constantine    Algeria  Africa   Africa       ...
# 1     Consumer  New South Wales  Australia    APAC  Oceania       ...
# 2     Consumer         Budapest    Hungary    EMEA     EMEA       ...
# 3  Home Office        Stockholm     Sweden      EU    North       ...
# 4     Consumer  New South Wales  Australia    APAC  Oceania       ...
#
#   discount   profit shipping_cost order_priority  year  converted_order_date  \
# ...

# %%
df['cost_to_company'].max()
# Out:
# 933.57

# %%
df[df['cost_to_company']==max(df['cost_to_company'])]
# Out:
#              order_id order_date  ship_date ship_mode customer_name   segment  \
# 13891  CA-2012-124891  7/31/2012  7/31/2012  Same Day   Rick Hansen  Consumer
#
#           state        country market region       ...       discount  \
# 13891  New York  United States     US   East       ...            0.0
#
#          profit shipping_cost order_priority  year  converted_order_date  \
# 13891  762.1845        933.57       Critical  2012            2012-07-31
#
#        order_date_year  order_date_month  order_date_week cost_to_company
# 13891             2012                 7               31          933.57
#
# [1 rows x 26 columns]

# %%
df[df['cost_to_company']==max(df['cost_to_company'])]['product_name']
# Out:
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
# <ipython-input-134-651dc4d24910> in <module>()
# ----> 1 df[df['cost_to_company']==max(df['cost_to_company'])]['product_name']
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in wrapper(self, other, axis)
#    1251
#    1252             with np.errstate(all='ignore'):
# -> 1253                 res = na_op(values, other)
#    1254             if is_scalar(res):
#    1255                 raise TypeError('Could not compare {typ} type with Series'
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in na_op(x, y)
#    1138
#    1139         elif is_object_dtype(x.dtype):
# -> 1140             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1141
#    1142         elif is_datetimelike_v_numeric(x, y):
#
# ~\Anaconda3\lib\site-packages\pandas\core\ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
# ...

# %%
df = df['cost_to_company']= df['discount'] + df['shipping_cost']

# %%
df.drop('cost_to_company')

# %%
#Dropping Column
df.drop('cost_to_company',axis=1,inplace=True) #Column deleted permanently because of inplace=True, axis = 1 means column operation
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-21f878725d6e> in <module>()
#       1 #Dropping Column
# ----> 2 df.drop('cost_to_company',axis=1,inplace=True) #Column deleted permanently because of inplace=True, axis = 1 means column operation
#
# ~\Anaconda3\lib\site-packages\pandas\core\series.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3411         return super(Series, self).drop(labels=labels, axis=axis, index=index,
#    3412                                         columns=columns, level=level,
# -> 3413                                         inplace=inplace, errors=errors)
#    3414
#    3415     @Substitution(**_shared_doc_kwargs)
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df.drop('cost_to_company')
# Out:
# 0    35.46
# 1     9.82
# 2     8.17
# 3     5.32
# 4      4.8
# dtype: object

# %%
df = df.drop('cost_to_company', axis =1)

# %%
df.drop('cost_to_company', axis =1, inplace = True)

# %%
df.head()

# %%
df.drop(1, inplace=True)

# %%
df.head()

# %%
df.loc[[2,3]]

# %%
df.loc[2:10]

# %%
df.loc[2:10:2]

# %%
df.loc[0:4,['order_id','order_date','ship_date']]

# %%
df.loc[0:4,0:3]

# %%
df.iloc[0:4,0:3]

# %%
df.iloc[1:5,3:6]

# %%
df.loc[1:5,['ship_mode','customer_name','segment']]

# %%
df

# %%
df[df>100]

# %%
df.dtypes

# %%
df.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')]

# %%
df[df.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')].index]

# %%
df2 =df[df.dtypes[(df.dtypes == 'float64') | (df.dtypes == 'int64')].index]

# %%
df3 = df2>100

# %%
df3

# %%
df3.dropna()

# %%
df3.dropna(axis=1)

# %%
df3.dropna(thresh = 5)

# %%
df3.fillna(value=4)

# %%
df3.fillna(value= df3['quantity'].mean())

# %%
df3.fillna(value= df3['profit'].mean())

# %%
df

# %%
df.groupby('year')

# %%
df.groupby('year')['profit'].mean()

# %%
df.groupby('year')['shipping_cost'].mean()

# %%
df.groupby('year')['discount'].mean()

# %%
df.columns

# %%
df[['country','market']]

# %%
df.sales

# %%
df.groupby('year')['sales'].mean()

# %%
df.sales

# %%
df.sales.str.replace(',',"").astype(int)

# %%
df['sales']=df.sales.str.replace(',',"").astype(int)

# %%
df.dtypes

# %%
df.groupby('year')['sales'].mean()

# %%
df.groupby('year')['quantity'].sum()

# %%
df.groupby('year')['quantity'].mean()

# %%
df.groupby('year')['sales'].sum()
