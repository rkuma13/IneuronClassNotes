# %%
import pandas as pd

# %%
df= pd.read_excel(r'C:\Users\Rajan\Downloads\Attribute DataSet.xlsx')

# %%
pd.read_excel('Attribute DataSet.xlsx')
# Out:
#        Dress_ID     Style    Price  Rating  Size  Season         NeckLine  \
# 0    1006032852      Sexy      Low     4.6     M  Summer           o-neck
# 1    1212192089    Casual      Low     0.0     L  Summer           o-neck
# 2    1190380701   vintage     High     0.0     L  Automn           o-neck
# 3     966005983     Brief  Average     4.6     L  Spring           o-neck
# 4     876339541      cute      Low     4.5     M  Summer           o-neck
# 5    1068332458  bohemian      Low     0.0     M  Summer           v-neck
# 6    1220707172    Casual  Average     0.0    XL  Summer           o-neck
# 7    1219677488   Novelty  Average     0.0  free  Automn           o-neck
# 8    1113094204     Flare  Average     0.0  free  Spring           v-neck
# 9     985292672  bohemian      Low     0.0  free  Summer           v-neck
# 10   1117293701     party  Average     5.0  free  Summer           o-neck
# 11    898481530     Flare  Average     0.0  free  Spring           v-neck
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df
# Out:
#        Dress_ID     Style    Price  Rating  Size  Season         NeckLine  \
# 0    1006032852      Sexy      Low     4.6     M  Summer           o-neck
# 1    1212192089    Casual      Low     0.0     L  Summer           o-neck
# 2    1190380701   vintage     High     0.0     L  Automn           o-neck
# 3     966005983     Brief  Average     4.6     L  Spring           o-neck
# 4     876339541      cute      Low     4.5     M  Summer           o-neck
# 5    1068332458  bohemian      Low     0.0     M  Summer           v-neck
# 6    1220707172    Casual  Average     0.0    XL  Summer           o-neck
# 7    1219677488   Novelty  Average     0.0  free  Automn           o-neck
# 8    1113094204     Flare  Average     0.0  free  Spring           v-neck
# 9     985292672  bohemian      Low     0.0  free  Summer           v-neck
# 10   1117293701     party  Average     5.0  free  Summer           o-neck
# 11    898481530     Flare  Average     0.0  free  Spring           v-neck
# ...

# %%
pd.read_excel(r'C:\Users\Rajan\Downloads\Attribute DataSet 2.xlsx',sheet_name='Rajan',header = None)
# Out:
#         0    1    2    3    4
# 0  kkajkj   kk    k    k    k
# 1    jkjk  ddd  NaN  NaN  NaN
# 2   kdkdj   dd  NaN  NaN  NaN
# 3   kkdjd    d  NaN  NaN  NaN
# 4      aa    d  NaN  NaN  NaN
# 5     NaN   dd  NaN  NaN  NaN

# %%
pd.read_excel(r'C:\Users\Rajan\Downloads\Attribute DataSet 2.xlsx',sheet_name='Rajan',header = None,names=['a','b','c','d','e'])
# Out:
#         a    b    c    d    e
# 0  kkajkj   kk    k    k    k
# 1    jkjk  ddd  NaN  NaN  NaN
# 2   kdkdj   dd  NaN  NaN  NaN
# 3   kkdjd    d  NaN  NaN  NaN
# 4      aa    d  NaN  NaN  NaN
# 5     NaN   dd  NaN  NaN  NaN

# %%
df.head(2)
# Out:
#      Dress_ID   Style Price  Rating Size  Season NeckLine SleeveLength  \
# 0  1006032852    Sexy   Low     4.6    M  Summer   o-neck    sleevless
# 1  1212192089  Casual   Low     0.0    L  Summer   o-neck        Petal
#
#   waiseline    Material FabricType Decoration Pattern Type  Recommendation
# 0    empire         NaN    chiffon    ruffles       animal               1
# 1   natural  microfiber        NaN    ruffles       animal               0

# %%
df.tail()
# Out:
#       Dress_ID   Style    Price  Rating  Size  Season   NeckLine SleeveLength  \
# 495  713391965  Casual      Low     4.7     M  Spring     o-neck         full
# 496  722565148    Sexy      Low     4.3  free  Summer     o-neck         full
# 497  532874347  Casual  Average     4.7     M  Summer     v-neck         full
# 498  655464934  Casual  Average     4.6     L  winter  boat-neck    sleevless
# 499  919930954  Casual      Low     4.4  free  Summer     v-neck        short
#
#     waiseline  Material  FabricType Decoration Pattern Type  Recommendation
# 495   natural  polyster         NaN        NaN        solid               1
# 496    empire    cotton         NaN        NaN          NaN               0
# 497    empire    cotton         NaN       lace        solid               1
# 498    empire      silk  broadcloth   applique        print               1
# 499    empire    cotton    Corduroy       lace        solid               0

# %%
pd.read_csv(r'C:\Users\Rajan\Downloads\haberman.csv')
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# 5    33  60   0    1
# 6    34  59   0    2
# 7    34  66   9    2
# 8    34  58  30    1
# 9    34  60   1    1
# 10   34  61  10    1
# 11   34  67   7    1
# 12   34  60   0    1
# 13   35  64  13    1
# 14   35  63   0    1
# 15   36  60   1    1
# 16   36  69   0    1
# 17   37  60   0    1
# 18   37  63   0    1
# 19   37  58   0    1
# 20   37  59   6    1
# 21   37  60  15    1
# 22   37  63   0    1
# 23   38  69  21    2
# 24   38  59   2    1
# 25   38  60   0    1
# 26   38  60   0    1
# 27   38  62   3    1
# 28   38  64   1    1
# 29   38  66   0    1
# ..   ..  ..  ..  ...
# 275  67  66   0    1
# 276  67  61   0    1
# 277  67  65   0    1
# 278  68  67   0    1
# 279  68  68   0    1
# 280  69  67   8    2
# 281  69  60   0    1
# 282  69  65   0    1
# 283  69  66   0    1
# 284  70  58   0    2
# 285  70  58   4    2
# ...

# %%
pd.read_csv(r'C:\Users\Rajan\Downloads\haberman.csv', header=None, names=['Age',"Patient's year of operation", 'Number of positive', 'Survival status'])
# Out:
#      Age  Patient's year of operation  Number of positive  Survival status
# 0     30                           64                   1                1
# 1     30                           62                   3                1
# 2     30                           65                   0                1
# 3     31                           59                   2                1
# 4     31                           65                   4                1
# 5     33                           58                  10                1
# 6     33                           60                   0                1
# 7     34                           59                   0                2
# 8     34                           66                   9                2
# 9     34                           58                  30                1
# 10    34                           60                   1                1
# ...

# %%
pd.read_csv(r'C:\Users\Rajan\Downloads\haberman1.csv')
# Out:
#       30@64@1@1
# 0     30@62@3@1
# 1     30@65@0@1
# 2     31@59@2@1
# 3     31@65@4@1
# 4    33@58@10@1
# 5     33@60@0@1
# 6     34@59@0@2
# 7     34@66@9@2
# 8    34@58@30@1
# 9     34@60@1@1
# 10   34@61@10@1
# 11    34@67@7@1
# 12    34@60@0@1
# 13   35@64@13@1
# 14    35@63@0@1
# 15    36@60@1@1
# 16    36@69@0@1
# 17    37@60@0@1
# 18    37@63@0@1
# 19    37@58@0@1
# 20    37@59@6@1
# 21   37@60@15@1
# 22    37@63@0@1
# 23   38@69@21@2
# 24    38@59@2@1
# 25    38@60@0@1
# 26    38@60@0@1
# 27    38@62@3@1
# 28    38@64@1@1
# 29    38@66@0@1
# ..          ...
# 275   67@66@0@1
# 276   67@61@0@1
# 277   67@65@0@1
# 278   68@67@0@1
# 279   68@68@0@1
# 280   69@67@8@2
# 281   69@60@0@1
# 282   69@65@0@1
# 283   69@66@0@1
# 284   70@58@0@2
# 285   70@58@4@2
# 286  70@66@14@1
# 287   70@67@0@1
# 288   70@68@0@1
# 289   70@59@8@1
# 290   70@63@0@1
# 291   71@68@2@1
# 292   72@63@0@2
# 293   72@58@0@1
# 294   72@64@0@1
# 295   72@67@3@1
# 296   73@62@0@1
# 297   73@68@0@1
# ...

# %%
pd.read_csv(r'C:\Users\Rajan\Downloads\haberman1.csv',sep='@')
# Out:
#      30  64   1  1.1
# 0    30  62   3    1
# 1    30  65   0    1
# 2    31  59   2    1
# 3    31  65   4    1
# 4    33  58  10    1
# 5    33  60   0    1
# 6    34  59   0    2
# 7    34  66   9    2
# 8    34  58  30    1
# 9    34  60   1    1
# 10   34  61  10    1
# 11   34  67   7    1
# 12   34  60   0    1
# 13   35  64  13    1
# 14   35  63   0    1
# 15   36  60   1    1
# 16   36  69   0    1
# 17   37  60   0    1
# 18   37  63   0    1
# 19   37  58   0    1
# 20   37  59   6    1
# 21   37  60  15    1
# 22   37  63   0    1
# 23   38  69  21    2
# 24   38  59   2    1
# 25   38  60   0    1
# 26   38  60   0    1
# 27   38  62   3    1
# 28   38  64   1    1
# 29   38  66   0    1
# ..   ..  ..  ..  ...
# 275  67  66   0    1
# 276  67  61   0    1
# 277  67  65   0    1
# 278  68  67   0    1
# 279  68  68   0    1
# 280  69  67   8    2
# 281  69  60   0    1
# 282  69  65   0    1
# 283  69  66   0    1
# 284  70  58   0    2
# 285  70  58   4    2
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Smarket.csv')
# Out:
#       Year   Lag1   Lag2   Lag3   Lag4   Lag5   Volume  Today Direction
# 0     2001  0.381 -0.192 -2.624 -1.055  5.010  1.19130  0.959        Up
# 1     2001  0.959  0.381 -0.192 -2.624 -1.055  1.29650  1.032        Up
# 2     2001  1.032  0.959  0.381 -0.192 -2.624  1.41120 -0.623      Down
# 3     2001 -0.623  1.032  0.959  0.381 -0.192  1.27600  0.614        Up
# 4     2001  0.614 -0.623  1.032  0.959  0.381  1.20570  0.213        Up
# 5     2001  0.213  0.614 -0.623  1.032  0.959  1.34910  1.392        Up
# 6     2001  1.392  0.213  0.614 -0.623  1.032  1.44500 -0.403      Down
# 7     2001 -0.403  1.392  0.213  0.614 -0.623  1.40780  0.027        Up
# 8     2001  0.027 -0.403  1.392  0.213  0.614  1.16400  1.303        Up
# 9     2001  1.303  0.027 -0.403  1.392  0.213  1.23260  0.287        Up
# 10    2001  0.287  1.303  0.027 -0.403  1.392  1.30900 -0.498      Down
# 11    2001 -0.498  0.287  1.303  0.027 -0.403  1.25800 -0.189      Down
# ...

# %%
pd.read_csv('https://raw.githubusercontent.com/selva86/datasets/master/Advertising.csv')
# Out:
#      Unnamed: 0     TV  radio  newspaper  sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# 5             6    8.7   48.9       75.0    7.2
# 6             7   57.5   32.8       23.5   11.8
# 7             8  120.2   19.6       11.6   13.2
# 8             9    8.6    2.1        1.0    4.8
# 9            10  199.8    2.6       21.2   10.6
# 10           11   66.1    5.8       24.2    8.6
# 11           12  214.7   24.0        4.0   17.4
# 12           13   23.8   35.1       65.9    9.2
# 13           14   97.5    7.6        7.2    9.7
# 14           15  204.1   32.9       46.0   19.0
# 15           16  195.4   47.7       52.9   22.4
# 16           17   67.8   36.6      114.0   12.5
# 17           18  281.4   39.6       55.8   24.4
# 18           19   69.2   20.5       18.3   11.3
# ...

# %%
pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')
# Out:
# [      Rk                 Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   \
#  0      1             Quincy Acy   PF   24  NYK  68  22  1287  152   331  ...
#  1      2           Jordan Adams   SG   20  MEM  30   0   248   35    86  ...
#  2      3           Steven Adams    C   21  OKC  70  67  1771  217   399  ...
#  3      4            Jeff Adrien   PF   28  MIN  17   0   215   19    44  ...
#  4      5          Arron Afflalo   SG   29  TOT  78  72  2502  375   884  ...
#  5      5          Arron Afflalo   SG   29  DEN  53  53  1750  281   657  ...
#  6      5          Arron Afflalo   SG   29  POR  25  19   752   94   227  ...
#  7      6          Alexis Ajinça    C   26  NOP  68   8   957  181   329  ...
#  8      7         Furkan Aldemir   PF   23  PHI  41   9   540   40    78  ...
#  9      8           Cole Aldrich    C   26  NYK  61  16   976  144   301  ...
#  10     9      LaMarcus Aldridge   PF   29  POR  71  71  2512  659  1415  ...
# ...

# %%
a=pd.read_html('https://www.basketball-reference.com/leagues/NBA_2015_totals.html')

# %%
type(a)
# Out:
# list

# %%
len(a)
# Out:
# 1

# %%
a[0]
# Out:
#       Rk                 Player  Pos  Age   Tm   G  GS    MP   FG   FGA  ...   \
# 0      1             Quincy Acy   PF   24  NYK  68  22  1287  152   331  ...
# 1      2           Jordan Adams   SG   20  MEM  30   0   248   35    86  ...
# 2      3           Steven Adams    C   21  OKC  70  67  1771  217   399  ...
# 3      4            Jeff Adrien   PF   28  MIN  17   0   215   19    44  ...
# 4      5          Arron Afflalo   SG   29  TOT  78  72  2502  375   884  ...
# 5      5          Arron Afflalo   SG   29  DEN  53  53  1750  281   657  ...
# 6      5          Arron Afflalo   SG   29  POR  25  19   752   94   227  ...
# 7      6          Alexis Ajinça    C   26  NOP  68   8   957  181   329  ...
# 8      7         Furkan Aldemir   PF   23  PHI  41   9   540   40    78  ...
# 9      8           Cole Aldrich    C   26  NYK  61  16   976  144   301  ...
# 10     9      LaMarcus Aldridge   PF   29  POR  71  71  2512  659  1415  ...
# ...

# %%
pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')
# Out:
#     active_lock_reason                                           assignee  \
# 0                  NaN                                               None
# 1                  NaN                                               None
# 2                  NaN                                               None
# 3                  NaN                                               None
# 4                  NaN                                               None
# 5                  NaN                                               None
# 6                  NaN                                               None
# 7                  NaN                                               None
# 8                  NaN                                               None
# 9                  NaN                                               None
# 10                 NaN                                               None
# 11                 NaN                                               None
# ...

# %%
js = pd.read_json('https://api.github.com/repos/pandas-dev/pandas/issues')

# %%
js['user']
# Out:
# 0     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 1     {'login': 'shourya5', 'id': 73142986, 'node_id...
# 2     {'login': 'adrienpacifico', 'id': 6614121, 'no...
# 3     {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 4     {'login': 'attack68', 'id': 24256554, 'node_id...
# 5     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 6     {'login': 'MarcoGorelli', 'id': 33491632, 'nod...
# 7     {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 8     {'login': 'jbrockmendel', 'id': 8078968, 'node...
# 9     {'login': 'GivyBoy', 'id': 58392771, 'node_id'...
# 10    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 11    {'login': 'SomtochiUmeh', 'id': 74836691, 'nod...
# 12    {'login': 'adrienpacifico', 'id': 6614121, 'no...
# 13    {'login': 'Brinkhuis', 'id': 3044985, 'node_id...
# 14    {'login': 'mroeschke', 'id': 10647082, 'node_i...
# 15    {'login': 'twoertwein', 'id': 6618166, 'node_i...
# 16    {'login': 'parthi-siva', 'id': 25401444, 'node...
# ...

# %%
js.columns
# Out:
# Index(['active_lock_reason', 'assignee', 'assignees', 'author_association',
#        'body', 'closed_at', 'comments', 'comments_url', 'created_at', 'draft',
#        'events_url', 'html_url', 'id', 'labels', 'labels_url', 'locked',
#        'milestone', 'node_id', 'number', 'performed_via_github_app',
#        'pull_request', 'reactions', 'repository_url', 'state', 'state_reason',
#        'timeline_url', 'title', 'updated_at', 'url', 'user'],
#       dtype='object')

# %%
js['user'][0]
# Out:
# {'login': 'jbrockmendel',
#  'id': 8078968,
#  'node_id': 'MDQ6VXNlcjgwNzg5Njg=',
#  'avatar_url': 'https://avatars.githubusercontent.com/u/8078968?v=4',
#  'gravatar_id': '',
#  'url': 'https://api.github.com/users/jbrockmendel',
#  'html_url': 'https://github.com/jbrockmendel',
#  'followers_url': 'https://api.github.com/users/jbrockmendel/followers',
#  'following_url': 'https://api.github.com/users/jbrockmendel/following{/other_user}',
#  'gists_url': 'https://api.github.com/users/jbrockmendel/gists{/gist_id}',
#  'starred_url': 'https://api.github.com/users/jbrockmendel/starred{/owner}{/repo}',
#  'subscriptions_url': 'https://api.github.com/users/jbrockmendel/subscriptions',
#  'organizations_url': 'https://api.github.com/users/jbrockmendel/orgs',
#  'repos_url': 'https://api.github.com/users/jbrockmendel/repos',
#  'events_url': 'https://api.github.com/users/jbrockmendel/events{/privacy}',
#  'received_events_url': 'https://api.github.com/users/jbrockmendel/received_events',
# ...

# %%
df.to_json('test123.json')

# %%
pwd
# Out:
# 'C:\\Users\\Rajan'

# %%
df.to_csv('E:\\test.csv')

# %%
df.to_csv('E:\\test123.csv',sep="#")

# %%
df.to_csv('E:\\test1234.csv',index=False)
